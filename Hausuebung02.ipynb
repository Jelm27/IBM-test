# %% [markdown]
# ### Hausübungsblatt 2
#
# Organisatorisches:
#
# 1. Bearbeiten Sie dieses Übungsblatt in Gruppen von 2-4 Leuten. (Das bedeutet insbesondere, dass Sie **keine Einzelabgaben** abgeben sollen!)
# 2. Schreiben Sie die Namen und Matrikelnummern **aller** Gruppenmitglieder in die nachfolgende Tabelle.
# 3. Geben Sie Ihre Lösung **bis spätestens** am 08.12.2022 23:59 im ILIAS Kurs unter folgendem Link ab: https://ilias.uni-hannover.de/goto.php?target=crs_148748_rcodeYLGQrU9bfr&client_id=ilias
#
# Bei jeder Aufgabe können Sie maximal 10 Punkte erreichen.
# Wenn Sie Ihre Lösung als jupyter notebook abgeben (ggf. als .zip mit einem notebook und eventuellen Bildern, die eingefügt werden), bekommen Sie einen Extrapunkt.

# %% [markdown]
# |Name|Matrikelnummer|
# |----|--------------|
# |Jorge Lobaton|10032159|
# |Ashraf||
# |||
# |||

# %% [markdown]
# Sie kennen aus Vorlesung und Übung den Algorithmus von Dijkstra zur Berechnung von kürzesten Pfaden. In den folgenden beiden Aufgaben sollen Sie ihn benutzen, um einen kürzesten Pfad in einem vereinfachten Netzwerk des öffentlichen Nahverkehrs zu finden.

# %% [markdown]
# #### Aufgabe 1
#
# $\left(\begin{array}{c|cccc}
# H0 & H1 & H2 & H3 & H4\\
# \hline
# 0 & \infty & \infty & \infty & \infty\\
# 1 & \infty & \infty & \infty & \infty\\
# 2 & \infty & \infty & \infty & \infty\\
# 3 & \infty & \infty & \infty & \infty\\
# 4 & \infty & \infty & \infty & \infty\\
# 5 & \infty & \infty & \infty & \infty\\
# 6 & \infty & \infty & \infty & \infty\\
# 7 & \infty & \infty & \infty & \infty\\
# 8 & 1 & \infty & \infty & \infty\\
# 9 & \infty & 1 & \infty & \infty\\
# 10 & \infty & \infty & \infty & \infty\\
# 11 & \infty & \infty & \infty & \infty\\
# 12 & \infty & \infty & \infty & \infty\\
# 13 & \infty & \infty & \infty & \infty\\
# 14 & \infty & \infty & \infty & \infty\\
# 15 & \infty & \infty & \infty & \infty\\
# 16 & \infty & \infty & \infty & \infty\\
# 17 & \infty & \infty & \infty & \infty\\
# 18 & \infty & \infty & \infty & \infty\\
# 19 & \infty & \infty & \infty & \infty\\
# 20 & \infty & \infty & \infty & \infty\\
# 21 & \infty & \infty & \infty & \infty\\
# 22 & \infty & \infty & \infty & \infty\\
# 23 & \infty & \infty & \infty & \infty\\
# \end{array}\right)$
# $\left(\begin{array}{c|cccc}
# H1 & H0 & H2 & H3 & H4\\
# \hline
# 0 & \infty & \infty & \infty & \infty\\
# 1 & \infty & \infty & \infty & \infty\\
# 2 & \infty & \infty & \infty & \infty\\
# 3 & \infty & \infty & \infty & \infty\\
# 4 & \infty & \infty & \infty & \infty\\
# 5 & \infty & \infty & \infty & \infty\\
# 6 & \infty & \infty & \infty & \infty\\
# 7 & \infty & \infty & \infty & \infty\\
# 8 & \infty & \infty & \infty & 1\\
# 9 & \infty & \infty & \infty & \infty\\
# 10 & \infty & \infty & 1 & \infty\\
# 11 & \infty & \infty & \infty & \infty\\
# 12 & \infty & \infty & \infty & \infty\\
# 13 & \infty & \infty & \infty & \infty\\
# 14 & \infty & \infty & \infty & \infty\\
# 15 & \infty & \infty & \infty & \infty\\
# 16 & \infty & \infty & \infty & \infty\\
# 17 & \infty & \infty & \infty & \infty\\
# 18 & \infty & \infty & \infty & \infty\\
# 19 & \infty & \infty & 3 & \infty\\
# 20 & \infty & \infty & \infty & \infty\\
# 21 & \infty & \infty & \infty & \infty\\
# 22 & \infty & \infty & \infty & \infty\\
# 23 & \infty & \infty & \infty & \infty\\
# \end{array}\right)$
# $\left(\begin{array}{c|cccc}
# H2 & H0 & H1 & H3 & H4\\
# \hline
# 0 & \infty & \infty & \infty & \infty\\
# 1 & \infty & \infty & \infty & \infty\\
# 2 & \infty & \infty & \infty & \infty\\
# 3 & \infty & \infty & \infty & \infty\\
# 4 & \infty & \infty & \infty & \infty\\
# 5 & \infty & \infty & \infty & \infty\\
# 6 & \infty & \infty & \infty & \infty\\
# 7 & \infty & \infty & \infty & \infty\\
# 8 & \infty & \infty & \infty & \infty\\
# 9 & \infty & \infty & \infty & \infty\\
# 10 & \infty & \infty & \infty & \infty\\
# 11 & \infty & \infty & \infty & \infty\\
# 12 & \infty & \infty & \infty & \infty\\
# 13 & \infty & \infty & \infty & \infty\\
# 14 & \infty & \infty & \infty & \infty\\
# 15 & \infty & \infty & \infty & 0.5\\
# 16 & \infty & \infty & \infty & \infty\\
# 17 & \infty & \infty & \infty & \infty\\
# 18 & \infty & \infty & \infty & \infty\\
# 19 & \infty & \infty & \infty & \infty\\
# 20 & \infty & \infty & \infty & \infty\\
# 21 & \infty & \infty & \infty & \infty\\
# 22 & \infty & \infty & \infty & \infty\\
# 23 & \infty & \infty & \infty & \infty\\
# \end{array}\right)$
#
# $\left(\begin{array}{c|cccc}
# H3 & H0 & H1 & H2 & H4\\
# \hline
# 0 & \infty & \infty & \infty & \infty\\
# 1 & \infty & \infty & \infty & \infty\\
# 2 & \infty & \infty & \infty & \infty\\
# 3 & \infty & \infty & \infty & \infty\\
# 4 & \infty & \infty & \infty & \infty\\
# 5 & \infty & \infty & \infty & \infty\\
# 6 & \infty & \infty & \infty & \infty\\
# 7 & \infty & \infty & \infty & \infty\\
# 8 & \infty & \infty & \infty & \infty\\
# 9 & \infty & \infty & \infty & \infty\\
# 10 & \infty & \infty & \infty & \infty\\
# 11 & \infty & \infty & \infty & \infty\\
# 12 & \infty & \infty & \infty & \infty\\
# 13 & \infty & \infty & \infty & \infty\\
# 14 & \infty & \infty & 0.5 & \infty\\
# 15 & \infty & \infty & \infty & 1.5\\
# 16 & \infty & \infty & \infty & \infty\\
# 17 & \infty & \infty & \infty & \infty\\
# 18 & \infty & \infty & \infty & \infty\\
# 19 & \infty & \infty & \infty & \infty\\
# 20 & \infty & \infty & \infty & \infty\\
# 21 & \infty & \infty & \infty & \infty\\
# 22 & \infty & \infty & \infty & \infty\\
# 23 & \infty & \infty & 2 & \infty\\
# \end{array}\right)$
# $\left(\begin{array}{c|cccc}
# H4 & H0 & H1 & H2 & H3\\
# \hline
# 0 & \infty & \infty & \infty & \infty\\
# 1 & \infty & \infty & \infty & \infty\\
# 2 & \infty & \infty & \infty & \infty\\
# 3 & \infty & \infty & \infty & \infty\\
# 4 & \infty & \infty & \infty & \infty\\
# 5 & \infty & \infty & \infty & \infty\\
# 6 & \infty & \infty & \infty & \infty\\
# 7 & \infty & \infty & \infty & \infty\\
# 8 & \infty & \infty & \infty & \infty\\
# 9 & \infty & \infty & \infty & \infty\\
# 10 & \infty & \infty & \infty & \infty\\
# 11 & \infty & \infty & \infty & \infty\\
# 12 & \infty & \infty & \infty & \infty\\
# 13 & 1 & \infty & \infty & 1\\
# 14 & \infty & \infty & \infty & \infty\\
# 15 & \infty & \infty & \infty & \infty\\
# 16 & \infty & \infty & \infty & \infty\\
# 17 & \infty & \infty & \infty & \infty\\
# 18 & \infty & \infty & \infty & \infty\\
# 19 & \infty & \infty & \infty & \infty\\
# 20 & \infty & \infty & \infty & \infty\\
# 21 & \infty & \infty & \infty & \infty\\
# 22 & \infty & \infty & \infty & \infty\\
# 23 & \infty & \infty & \infty & \infty\\
# \end{array}\right)$

# %% [markdown]
# Die oben angegebenen Matrizen spannen das Fahrplannetz zwischen 5 Haltestellen auf. Der Eintrag in Zeile $i$ und Spalte $j$ von Matrix $Hk$ bedeutet, dass um $i$ Uhr eine Bahn von Haltestelle $Hk$ zu Haltestelle $Hj$ fährt und dafür $Hk[i, j]$ Stunden braucht. Ist der Eintrag $Hk[i, j]$ $\infty$, so fährt zu dieser Uhrzeit keine Bahn die entsprechende Strecke.
# Beispielsweise fährt also um 8:00 eine Bahn von Haltestelle $H0$ zu $H1$ und braucht dafür eine Stunde.
#
# 1.1  Konstruieren Sie dazu einen Graphen, bei dem die Knoten den gegebenen Haltestellen entsprechen und die Kanten Informationen über Start- und Ankunftszeit enthalten, sodass in diesem anschließend mit (einer leichten Abwandlung von) dem Algorithmus von Dijkstra ein kürzester Pfad gesucht werden kann. *(Kanten haben also nicht wie gewohnt einfache Gewichte, sondern Beschriftungen der Form $s-t$, wobei $s$ die Start- und $t$ die Ankunftszeit ist.)*
# *(Beachten Sie, dass das bedeutet, dass es zwischen zwei Haltestellen auch mehr als eine Kante geben kann, wenn zu unterschiedlichen Uhrzeiten eine Bahn fährt.)*
# Sie können jeweils annehmen, dass Sie auf jeden Fall heute ankommen möchten.
# Fahrten, die erst morgen ankämen, brauchen also **nicht** berücksichtigt zu werden.
# (Auch nicht für den Implementierungsteil.)
# Ein kleines Beispiel für einen Fahrplan und einen Graphen ist unter der Aufgabenstellung zu sehen.
#
# 1.2 Implementieren Sie einen Algorithmus in python, der einen Fahrplan, entsprechend der obigen Form als Liste von Matrizen, als Eingabe bekommt und einen Graphen wie in Aufgabenteil 1.1 in Form von Adjazenzlisten ausgibt.
# (Hier muss nun für jede ausgehende Kante eines Knotens ein Element der Adjazenzliste hinzugefügt werden.
# Falls es mehrere Kanten von einem Knoten zu einem anderen gibt, muss für jede dieser Kanten ein entsprechendes Element hinzugefügt werden.)
# Beschreiben Sie, wie Ihr Algorithmus arbeitet und dokumentieren Sie Ihre Implementierung (auf deutsch oder auf englisch)!
# *(Falls Beschreibung bzw. Dokumentation fehlen, gibt es für diese Aufgabe keine Punkte!)*
# Testen Sie Ihre Implementierung!
#
# 1.3 Analysieren Sie die asymptotische Laufzeit Ihrer Implementierung in Abhängigkeit der Anzahl an Haltestellen $n$ und geben Sie sie in $\mathcal{O}$-Notation an.

# %% [markdown]
# Beispiel:
#
# $\left(\begin{array}{c|cc}
# H0 & H1 & H2 \\
# \hline
# 0 & \infty & \infty \\
# 1 & \infty & \infty \\
# 2 & \infty & \infty \\
# 3 & \infty & \infty \\
# 4 & \infty & \infty \\
# 5 & \infty & \infty \\
# 6 & \infty & \infty \\
# 7 & \infty & \infty \\
# 8 & 2.42 & \infty \\
# 9 & \infty & \infty \\
# 10 & \infty & \infty \\
# 11 & 1 & \infty \\
# 12 & \infty & \infty \\
# 13 & \infty & \infty \\
# 14 & \infty & \infty \\
# 15 & \infty & \infty \\
# 16 & \infty & \infty \\
# 17 & \infty & \infty \\
# 18 & \infty & \infty \\
# 19 & \infty & \infty \\
# 20 & \infty & \infty \\
# 21 & \infty & \infty \\
# 22 & \infty & \infty \\
# 23 & \infty & \infty \\
# \end{array}\right)$
# $\left(\begin{array}{c|cc}
# H1 & H0 & H2 \\
# \hline
# 0 & \infty & \infty \\
# 1 & \infty & \infty \\
# 2 & \infty & \infty \\
# 3 & \infty & \infty \\
# 4 & \infty & \infty \\
# 5 & \infty & \infty \\
# 6 & \infty & \infty \\
# 7 & \infty & \infty \\
# 8 & 9 & \infty \\
# 9 & \infty & \infty \\
# 10 & \infty & \infty \\
# 11 & \infty & 2.37 \\
# 12 & \infty & \infty \\
# 13 & \infty & \infty \\
# 14 & \infty & \infty \\
# 15 & \infty & \infty \\
# 16 & \infty & \infty \\
# 17 & \infty & \infty \\
# 18 & \infty & \infty \\
# 19 & \infty & \infty \\
# 20 & \infty & \infty \\
# 21 & \infty & \infty \\
# 22 & \infty & \infty \\
# 23 & \infty & \infty \\
# \end{array}\right)$
# $\left(\begin{array}{c|cc}
# H2 & H0 & H1 \\
# \hline
# 0 & \infty & \infty \\
# 1 & \infty & \infty \\
# 2 & \infty & \infty \\
# 3 & \infty & \infty \\
# 4 & \infty & \infty \\
# 5 & \infty & \infty \\
# 6 & \infty & \infty \\
# 7 & \infty & \infty \\
# 8 & \infty & \infty \\
# 9 & \infty & \infty \\
# 10 & \infty & \infty \\
# 11 & \infty & \infty \\
# 12 & \infty & \infty \\
# 13 & \infty & \infty \\
# 14 & \infty & \infty \\
# 15 & \infty & \infty \\
# 16 & \infty & \infty \\
# 17 & \infty & \infty \\
# 18 & \infty & \infty \\
# 19 & \infty & \infty \\
# 20 & \infty & \infty \\
# 21 & \infty & \infty \\
# 22 & \infty & 5 \\
# 23 & \infty & \infty \\
# \end{array}\right)$
# <p align="left">
#   <img src="scheduling_graph_min_ex.png" />
# </p>

# %%
from typing import List, Tuple

def generate_graph(schedules:List[List[List[int]]]) -> List[List[Tuple[int, int, float]]]:
    """Function to generate a scheduling graph from a list of schedules. The scheduling graph is returned as
    adjacency lists [(destination, start_time, arrival_time)]. 
    In a graph of three nodes 0, 1 and 2 with the edges 0->1 from 8 to 10.42, 0->1 from 11 to 12,
    1->2 from 11 to 13.37 and 1->0 from 9 to 17, the respective representation would look as follows:
    [[(1, 8, 10.42), (1, 11, 12)], [(2, 11, 13.37), (0, 9, 17)]]"""
    pass

# %%
example = [[[float('inf')] * 24 for _ in range(3)] for _ in range(3)]

example[0][1][8] = 2.42
example[0][1][11] = 1

example[1][0][8] = 9
example[1][2][11] = 2.37

print(generate_graph(example))

h1 = [[[float('inf')] * 24 for _ in range(5)] for _ in range(5)]

h1[0][1][8] = 1
h1[0][2][9] = 1

h1[1][0][8] = 1
h1[1][3][10] = 1
h1[1][3][19] = 3

h1[2][4][15] = 0.5

h1[3][2][14] = 0.5
h1[3][4][15] = 1.5
h1[3][2][23] = 2

h1[4][0][13] = 1
h1[4][3][13] = 1

print(generate_graph(h1))

h2 = [[[float('inf')] * 24 for _ in range(4)] for _ in range(4)]

h2[0][1][4] = 1.5
h2[0][2][7] = 1
h2[0][3][9] = 8

h2[1][2][6] = 1.5
h2[1][3][6] = 6

h2[2][1][9] = 1
h2[2][3][9] = 2

h2[3][0][4] = 1

print(generate_graph(h2))

# %% [markdown]
# #### Aufgabe 2
#
# 2.1 Beschreiben Sie kurz, wie man den Algorithmus von Dijkstra abwandeln müsste, damit er auf Graphen der Form von Aufgabe 1 kürzeste Pfade finden kann.
# Wandeln Sie ihn dementsprechend ab und führen Sie ihn aus, um in dem unter dieser Aufgabenstellung gegebenen Graphen einen kürzesten Pfad von Haltestelle $H2$ ab 8:00 zu Haltestelle $H0$ zu finden.
# Dokumentieren Sie den Algorithmenablauf analog zur Notation, die Sie aus Vorlesung und Übung kennen.
#
# 2.2  Implementieren Sie die abgewandelte Version des Algorithmus' von Dijkstra in python, sodass dieser einen Graph der obigen Form als Eingabe bekommt, und einen kürzesten Pfad von der gewünschten Starthaltestelle zur gewünschten Zielhaltestelle anfangend zur gewünschten Startzeit, ausgibt.
# Falls es nicht möglich ist, heute noch anzukommen, soll eine entsprechende Meldung ausgegeben werden.
# Beschreiben Sie, wie Ihr Algorithmus arbeitet und dokumentieren Sie Ihre Implementierung (auf deutsch oder auf englisch)!
# *(Falls Beschreibung bzw. Dokumentation fehlen, gibt es für diese Aufgabe keine Punkte!)*
# Testen Sie Ihre Implementierung!
#
# 2.3 Analysieren Sie die asymptotische Laufzeit Ihrer Implementierung in Abhängigkeit der Anzahl an Knoten im Graphen $n$ und geben Sie sie in $\mathcal{O}$-Notation an.

# %% [markdown]
# <p align="center">
#   <img src="scheduling_graph_dijkstra.png" />
# </p>

# %% [markdown]
# |Schritt|$\textit{dist}(H2, H0), \textit{pred}(H0)$|$\textit{dist}(H2, H1), \textit{pred}(H1)$|$\textit{dist}(H2, H3), \textit{pred}(H3)$|$\textit{dist}(H2, H4), \textit{pred}(H4)$|PriorityQueue|
# |-------|--------------|--------------|--------------|--------------|--------------|
# |$0$|$\infty$|$\infty$|$\infty$|$\infty$|$H2$|
# |||||||
# |||||||
# |||||||
# |||||||

# %%
from queue import PriorityQueue
from typing import List, Tuple

def scheduling_dijkstra(graph:List[Tuple[int, int, float]], start:int, target:int, start_time:float) -> List[Tuple[int, float]]:
    """Implementation of Dijkstra's algorithm to determine a shortest path in the given scheduling graph. Takes a scheduling graph in 
    form of adjacency lists, a starting node, a starting time and a target node as its input and returns a shortest path from the 
    starting node to the target node. The path is given in the form of a list of tuples containing node and arrival time at that node
    in the path. A path which starts at node 0 at time 8, arrives at node 1 from node 0 at time 10.42 and reaches the target node 2
    at time 13.37 would be represented as [(0, 8), (1, 10.42), (2, 13.37)]."""
    pass

# %%
example = [[[float('inf')] * 24 for _ in range(3)] for _ in range(3)]

example[0][1][8] = 2.42
example[0][1][11] = 1

example[1][0][8] = 9
example[1][2][11] = 2.37

example_graph = generate_graph(example)
print(scheduling_dijkstra(example_graph, 0, 2, 6.66))

h1 = [[[float('inf')] * 24 for _ in range(5)] for _ in range(5)]

h1[2][4][8] = 1
h1[2][3][9] = 1

h1[4][2][8] = 1
h1[4][1][10] = 1
h1[4][1][19] = 3

h1[3][0][15] = 0.5

h1[1][3][14] = 0.5
h1[1][0][15] = 1.5
h1[1][3][23] = 2

h1[0][2][13] = 1
h1[0][1][13] = 1

graph1 = generate_graph(h1)
print(scheduling_dijkstra(graph1, 2, 0, 8))
print(scheduling_dijkstra(graph1, 2, 0, 12))

h2 = [[[float('inf')] * 24 for _ in range(4)] for _ in range(4)]

h2[0][1][4] = 1.5
h2[0][2][7] = 1
h2[0][3][9] = 8

h2[1][2][6] = 1.5
h2[1][3][6] = 6

h2[2][1][9] = 1
h2[2][3][9] = 2

h2[3][0][4] = 1

graph2 = generate_graph(h2)
print(scheduling_dijkstra(graph2, 0, 3, 2))

# %% [markdown]
# #### Aufgabe 3
#
# 3.1 Recherchieren Sie nach dem Counting-Sort Algorithmus.
# (Beispielsweise in https://www.tib.eu/de/suchen/id/TIBKAT:882894501/Algorithmen-eine-Einf%C3%BChrung?cHash=f935c66cb3df3620f17982d7758911d5 Kapitel 8.2)
# Erklären Sie, wie der Algorithmus funktioniert und führen Sie ihn auf der folgenden Liste händisch aus.
# Dokumentieren Sie die Zwischenschritte Ihrer Durchführung des Algorithmus sinnvoll, sodass der Algorithmenverlauf nachvollziehbar ist.
#
#     [7, 2, 3, 9, 1, 2, 1, 1, 9, 5, 5, 7]
#
# 3.2 Recherchieren Sie nach dem Radix-Sort Algorithmus.
# (Beispielsweise in https://www.tib.eu/de/suchen/id/TIBKAT:882894501/Algorithmen-eine-Einf%C3%BChrung?cHash=f935c66cb3df3620f17982d7758911d5 Kapitel 8.3)
# Erklären Sie, wie der Algorithmus funktioniert und führen Sie ihn auf der folgenden Liste händisch aus.
# Dokumentieren Sie die Zwischenschritte Ihrer Durchführung des Algorithmus sinnvoll, sodass der Algorithmenverlauf nachvollziehbar ist.
#
#     [132, 754, 23, 998, 1092, 2102, 2408, 43, 201, 1, 9, 124]
#
# 3.3 Implementieren Sie Radix-Sort mit Counting-Sort als Subroutine zum Sortieren von Listen von natürlichen Zahlen in python.
# Beschreiben Sie, wie Ihr Algorithmus arbeitet und dokumentieren Sie Ihre Implementierung (auf deutsch oder auf englisch)!
# *(Falls Beschreibung bzw. Dokumentation fehlen, gibt es für diese Aufgabe keine Punkte!)*
# Testen Sie Ihre Implementierung!

# %%
from typing import List

def counting_sort(input_list:List[int], digit:int) -> List[int]:
    """Counting Sort implementation that sorts its input list based on the given $digits digit of the elements
    in a stable manner, i.e., preserving previous order for equal elements.
    This means that e.g. the list [2024, 102, 13, 5], if sorted by the tenth place, would be sorted to [102, 5, 13, 2024]."""
    pass

# %%
from typing import List

def radix_sort(input_list:List[int]) -> List[int]:
    """Radix Sort implementation that sorts its input list by iteratively sorting by its digits."""
    pass

# %%
l1 = [132, 754, 23, 998, 1092, 2102, 2408, 43, 201, 1, 9, 124]
l2 = [0, 9, 0, 0]
l3 = [1230832403, 123, 2, 0, 5]

print(radix_sort(l1))
print(radix_sort(l2))
print(radix_sort(l3))
